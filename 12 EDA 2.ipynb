# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv(r"C:\ExcelR\DS\Assignment\EDA2\EDA2\adult_with_headers.csv")

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# # 1. Data Exploration and Preprocessing

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education_num        16
# marital_status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital_gain        119
# capital_loss         92
# hours_per_week       94
# native_country       42
# income                2
# dtype: int64

# %% [markdown]
# ### scaling techniques to numerical features:
# •	Standard Scaling
# •	Min-Max Scaling

# %%
from sklearn.preprocessing import StandardScaler , MinMaxScaler

# %%
numerical_cols= df.select_dtypes(include=['int64','float64']).columns

# %%
numerical_cols
# Out:
# Index(['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='object')

# %% [markdown]
# ### Standard Scaling

# %%
std_scalar= StandardScaler()

# %%
data= df.copy()

# %%
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data[numerical_cols]=std_scalar.fit_transform(df[numerical_cols])

# %%
data[numerical_cols]
# Out:
#             age    fnlwgt  education_num  capital_gain  capital_loss  \
# 0      0.030390 -1.063569       1.134777      0.148292     -0.216743
# 1      0.836973 -1.008668       1.134777     -0.145975     -0.216743
# 2     -0.042936  0.245040      -0.420679     -0.145975     -0.216743
# 3      1.056950  0.425752      -1.198407     -0.145975     -0.216743
# 4     -0.776193  1.408066       1.134777     -0.145975     -0.216743
# ...         ...       ...            ...           ...           ...
# 32556 -0.849519  0.639678       0.745913     -0.145975     -0.216743
# 32557  0.103716 -0.335436      -0.420679     -0.145975     -0.216743
# 32558  1.423579 -0.358779      -0.420679     -0.145975     -0.216743
# 32559 -1.216148  0.110930      -0.420679     -0.145975     -0.216743
# 32560  0.983625  0.929812      -0.420679      1.887635     -0.216743
#
#        hours_per_week
# 0           -0.035664
# 1           -2.222483
# 2           -0.035664
# 3           -0.035664
# ...

# %% [markdown]
# ### Min-Max Scaling

# %%
min_max_scale= MinMaxScaler()

# %%
data_min_max_scale= df.copy()

# %%
data_min_max_scale[numerical_cols]=min_max_scale.fit_transform(df[numerical_cols])

# %%
data_min_max_scale
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.301370          State-gov  0.044302    Bachelors       0.800000
# 1      0.452055   Self-emp-not-inc  0.048238    Bachelors       0.800000
# 2      0.287671            Private  0.138113      HS-grad       0.533333
# 3      0.493151            Private  0.151068         11th       0.400000
# 4      0.150685            Private  0.221488    Bachelors       0.800000
# ...         ...                ...       ...          ...            ...
# 32556  0.136986            Private  0.166404   Assoc-acdm       0.733333
# 32557  0.315068            Private  0.096500      HS-grad       0.533333
# 32558  0.561644            Private  0.094827      HS-grad       0.533333
# 32559  0.068493            Private  0.128499      HS-grad       0.533333
# 32560  0.479452       Self-emp-inc  0.187203      HS-grad       0.533333
#
#             marital_status          occupation    relationship    race  \
# ...

# %% [markdown]
# ### 2. Encoding Techniques

# %%
#One-Hot Encoding to Categorical Variables with Less Than 5 Categories

# %%
data_ohe= pd.get_dummies(data , columns=['sex','income'],drop_first=True)

# %%
data_ohe
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.030390          State-gov -1.063569    Bachelors       1.134777
# 1      0.836973   Self-emp-not-inc -1.008668    Bachelors       1.134777
# 2     -0.042936            Private  0.245040      HS-grad      -0.420679
# 3      1.056950            Private  0.425752         11th      -1.198407
# 4     -0.776193            Private  1.408066    Bachelors       1.134777
# ...         ...                ...       ...          ...            ...
# 32556 -0.849519            Private  0.639678   Assoc-acdm       0.745913
# 32557  0.103716            Private -0.335436      HS-grad      -0.420679
# 32558  1.423579            Private -0.358779      HS-grad      -0.420679
# 32559 -1.216148            Private  0.110930      HS-grad      -0.420679
# 32560  0.983625       Self-emp-inc  0.929812      HS-grad      -0.420679
#
#             marital_status          occupation    relationship    race  \
# ...

# %%
#Label Encoding for Categorical Variables with More Than 5 Categories

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
data['workclass'] = label_encoder.fit_transform(df['workclass'])

# %%
data
# Out:
#             age  workclass    fnlwgt    education  education_num  \
# 0      0.030390          7 -1.063569    Bachelors       1.134777
# 1      0.836973          6 -1.008668    Bachelors       1.134777
# 2     -0.042936          4  0.245040      HS-grad      -0.420679
# 3      1.056950          4  0.425752         11th      -1.198407
# 4     -0.776193          4  1.408066    Bachelors       1.134777
# ...         ...        ...       ...          ...            ...
# 32556 -0.849519          4  0.639678   Assoc-acdm       0.745913
# 32557  0.103716          4 -0.335436      HS-grad      -0.420679
# 32558  1.423579          4 -0.358779      HS-grad      -0.420679
# 32559 -1.216148          4  0.110930      HS-grad      -0.420679
# 32560  0.983625          5  0.929812      HS-grad      -0.420679
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ## 3. Feature Engineering:

# %%
#create 2 new features

# %%
df['capital_diff']= df['capital_gain'] - df['capital_loss']

# %%
df['age_group'] = pd.cut(df['age'],bins=[0,25,45,65,100], labels=['young','adult','senior','old'])

# %%
df[['capital_diff']]
# Out:
#        capital_diff
# 0              2174
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 32556             0
# 32557             0
# 32558             0
# 32559             0
# 32560         15024
#
# [32537 rows x 1 columns]

# %%
df[['age_group']]
# Out:
#       age_group
# 0         adult
# 1        senior
# 2         adult
# 3        senior
# 4         adult
# ...         ...
# 32556     adult
# 32557     adult
# 32558    senior
# 32559     young
# 32560    senior
#
# [32537 rows x 1 columns]

# %%
#Transformation to a Skewed Numerical Feature

# %%
df['log_capital_gain'] = np.log1p(df['capital_gain'])

# %%
df[['log_capital_gain']]
# Out:
#        log_capital_gain
# 0              7.684784
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.000000
# ...                 ...
# 32556          0.000000
# 32557          0.000000
# 32558          0.000000
# 32559          0.000000
# 32560          9.617471
#
# [32537 rows x 1 columns]

# %% [markdown]
# ## 4. Feature Selection

# %%
from sklearn.ensemble import IsolationForest

# %%
iso_forest = IsolationForest()

# %%
outliers = iso_forest.fit_predict(df[numerical_cols])

# %%
data_no_outliers = df[outliers == 1]

# %%
#data with no outliers
data_no_outliers
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32555   22            Private  310152   Some-college             10
# 32556   27            Private  257302     Assoc-acdm             12
# 32557   40            Private  154374        HS-grad              9
# 32558   58            Private  151910        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
#PPS (Predictive Power Score) to Find Relationships Between Features

# %%
import ppscore as pps

# %%
pps_matrix = pps.matrix(data_no_outliers).pivot(columns='x',index='y',values='ppscore')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# ...

# %%
correlation_matrix = data_no_outliers.corr()

# %%
pps_matrix, correlation_matrix
# Out:
# (x                          age     age_group  capital_diff  capital_gain  \
#  y
#  age               1.000000e+00  6.023438e-01      0.000000      0.000000
#  age_group         1.000000e+00  1.000000e+00      0.000000      0.000000
#  capital_diff      0.000000e+00  0.000000e+00      1.000000      0.975590
#  capital_gain      0.000000e+00  0.000000e+00      0.997475      1.000000
#  capital_loss      0.000000e+00  0.000000e+00      0.979129      0.000000
#  education         5.606646e-02  4.488028e-02      0.000000      0.000000
#  education_num     0.000000e+00  0.000000e+00      0.000000      0.000000
#  fnlwgt            0.000000e+00  0.000000e+00      0.000000      0.000000
#  hours_per_week    0.000000e+00  0.000000e+00      0.000000      0.000000
#  income            2.981769e-04  1.380440e-07      0.170055      0.170489
#  log_capital_gain  0.000000e+00  0.000000e+00      0.997459      0.997459
#  marital_status    3.030013e-01  2.756430e-01      0.000000      0.000000
# ...
