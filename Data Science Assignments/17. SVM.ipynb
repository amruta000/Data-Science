# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\ExcelR\DS\Assignment\SVM\SVM\mushroom.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 0        1167    sunken       scaly     white      no    anise
# 1        1037    sunken     fibrous       red      no    anise
# 2         309      flat     grooves    purple     yes     foul
# 3         282      bell       scaly      pink     yes    fishy
# 4         820      flat      smooth    yellow     yes    musty
# 5         389    convex     grooves      pink      no    spicy
# 6         330      bell      smooth     brown      no    anise
# 7          98   conical     fibrous     white     yes     none
# 8         597   conical     grooves     green     yes  pungent
# 9          16    convex       scaly     brown     yes   almond
#
#   gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 0      descending      distant     broad       pink  ...    partial
# 1         notched      crowded    narrow  chocolate  ...  universal
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  stalk_height  cap_diameter
# count  2000.000000   2000.000000   2000.000000
# mean    624.974000      8.449118     12.314345
# std     375.091938      3.697217      7.048845
# min       0.000000      2.000000      1.000000
# 25%     290.000000      5.291009      5.723521
# 50%     607.000000      8.318596     12.124902
# 75%     957.250000     11.781272     18.698605
# max    1279.000000     15.095066     25.000054

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# cap_shape                   0
# cap_surface                 0
# cap_color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_color                  0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_color_above_ring      0
# stalk_color_below_ring      0
# veil_type                   0
# veil_color                  0
# ring_number                 0
# ring_type                   0
# spore_print_color           0
# population                  0
# habitat                     0
# class                       0
# stalk_height                0
# cap_diameter                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1024

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df['class'] = label_encoder.fit_transform(df['class'])

# %%
# Encode all categorical features
df_encoded = pd.get_dummies(df)

# %%
df_encoded
# Out:
#       Unnamed: 0  class  stalk_height  cap_diameter  cap_shape_bell  \
# 0           1167      1     14.276173      5.054983               0
# 1           1037      0      3.952715     19.068319               0
# 2            309      1      9.054265      7.205884               0
# 3            282      1      5.226499     20.932692               1
# 4            820      1     14.037532     12.545245               0
# ...          ...    ...           ...           ...             ...
# 1985         877      0     13.020616      9.993008               0
# 1988         926      1      3.751597     18.868135               1
# 1989         289      0     13.134058     15.740028               0
# 1996        1160      1      6.500840     13.501957               0
# 1999        1073      1     13.066414     21.056642               0
#
#       cap_shape_conical  cap_shape_convex  cap_shape_flat  cap_shape_sunken  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# Define features and target variable
x = df_encoded.drop('class', axis=1)
y = df_encoded['class']

# %%
# Split the data (80% training, 20% testing)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
sns.pairplot(df,hue='class')

# %%
sns.countplot(x='class', data=df)
plt.title('Class Distribution')
# Out:
# Text(0.5, 1.0, 'Class Distribution')

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC(kernel='linear')

# %%
svm_model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.5663265306122449
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.35      0.21      0.26        72
#            1       0.63      0.77      0.69       124
#
#     accuracy                           0.57       196
#    macro avg       0.49      0.49      0.48       196
# weighted avg       0.53      0.57      0.53       196
#
# Confusion Matrix:
#  [[15 57]
#  [28 96]]

# %% [markdown]
# # 5. Visualization of SVM Results

# %%
# Assuming 2D data (reduce dimensions for visualization if necessary)
from sklearn.decomposition import PCA

# %%
# Apply PCA for dimensionality reduction (2 components for visualization)
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_test)

# %%
# Create a scatter plot of the PCA-transformed features
plt.figure(figsize=(10, 6))
plt.scatter(x_pca[:, 0], x_pca[:, 1], c=y_pred, cmap='coolwarm', s=50)
plt.title('SVM Classification Results')
plt.show()

# %% [markdown]
# # 6. Parameter Tuning and Optimization

# %%
# Hyperparameter tuning using GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
# Define the parameter grid
param_grid = {'C': [0.1, 1],
              'gamma': [1, 0.1, 0.01, 0.001],
              'kernel': ['']}

# %%
# Instantiate the GridSearchCV object
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=2)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=  12.5s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=  14.6s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=   9.8s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=   9.4s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=  13.6s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=  11.5s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=  13.5s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=  10.4s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=   9.7s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=  13.3s
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time=  12.6s
# ...

# %%
# Best parameters and accuracy
print("Best Parameters:", grid.best_params_)
print("Best Accuracy:", grid.best_score_)
# Out:
# Best Parameters: {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# Best Accuracy: 0.5923076923076923

# %%
# Testing different kernels
kernels = ['linear', 'rbf', 'poly']
for kernel in kernels:
    model = SVC(kernel=kernel)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    
    print(f"Kernel: {kernel}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("\n")
# Out:
# Kernel: linear
# Accuracy: 0.5663265306122449
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.35      0.21      0.26        72
#            1       0.63      0.77      0.69       124
#
#     accuracy                           0.57       196
#    macro avg       0.49      0.49      0.48       196
# weighted avg       0.53      0.57      0.53       196
#
#
#
# Kernel: rbf
# Accuracy: 0.6326530612244898
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        72
#            1       0.63      1.00      0.78       124
#
#     accuracy                           0.63       196
#    macro avg       0.32      0.50      0.39       196
# weighted avg       0.40      0.63      0.49       196
#
#
#
# Kernel: poly
# Accuracy: 0.6326530612244898
# Classification Report:
#                precision    recall  f1-score   support
#
# ...
